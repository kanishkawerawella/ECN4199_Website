# %% [markdown]
# # ECN 4199 - Week 2 Live Notebook
#
# ## Working with Data in Python
#
# This notebook introduces students to importing and exploring a hypothetical Labour Force Survey dataset using Python and pandas.
#
# Before editing, go to **File -> Save a copy in Drive**.

# %% [markdown]
# ## 1. Import pandas
#
# pandas is the main library we use for working with tabular data in Python.

# %%
import pandas as pd

# %% [markdown]
# ## 2. Load the Labour Force Survey dataset
#
# The dataset is available from the course website. If this URL does not work before the site is published, download the Excel file from the Week 2 page and upload it to Colab manually.

# %%
dataset_url = "https://kanishkawerawella.github.io/ECN4199_Website/data/LFS_Hypothetical_Dataset.xlsx"

data = pd.read_excel(dataset_url, sheet_name="LFS_Data")
dictionary = pd.read_excel(dataset_url, sheet_name="Variable Dictionary")

# %% [markdown]
# ## 3. Preview the data
#
# Use `head()` to inspect the first few observations.

# %%
data.head()

# %%
data.tail()

# %% [markdown]
# ## 4. Understand the structure
#
# Rows are observations. Columns are variables.

# %%
data.shape

# %%
data.columns

# %%
data.info()

# %% [markdown]
# ## 5. Read the variable dictionary
#
# A variable dictionary explains what each column means.

# %%
dictionary

# %% [markdown]
# ## 6. Summary statistics
#
# Use `describe()` for numerical variables.

# %%
data.describe()

# %% [markdown]
# ## 7. Frequency tables
#
# Use `value_counts()` for categorical variables.

# %%
data["Sex"].value_counts()

# %%
data["Employment_Status"].value_counts()

# %%
data["Education_Level"].value_counts()

# %% [markdown]
# ## 8. Interpretation
#
# Write three short observations about the labour market patterns you see in the dataset.
#
# 1.
# 2.
# 3.
